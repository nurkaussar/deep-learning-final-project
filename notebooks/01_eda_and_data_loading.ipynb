# %%
# 1. Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import os

# 2. Dataset overview (FER-2013)
classes = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

print(f"Target emotions: {classes}")

# 3. Simple Visualization (Example code)
# Later you will load real images here
def plot_example_structure():
    plt.figure(figsize=(10, 5))
    plt.bar(classes, [3995, 436, 4097, 7215, 4830, 3171, 4965])
    plt.title("Distribution of Emotions in FER-2013 (Training Set)")
    plt.ylabel("Number of Images")
    plt.show()

plot_example_structure()
# Out:
# Target emotions: ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']
